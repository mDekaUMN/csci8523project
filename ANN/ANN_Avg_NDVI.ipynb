# %% [markdown]
# #CSCI 8523 Fall 2022 - Phase I Modeling
# #### Maitrayee Deka, Josh Spitzer-Resnick
#
# ---
#
#
#
# ---

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

from keras.models import Sequential
from keras.layers import Dense

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import mean_squared_error
from math import sqrt

from sklearn.metrics import r2_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
avg_ndvi = pd.read_csv('/content/drive/Shareddrives/CSCI 8523 F22/Data/modis_avgs.csv')

# %%
avg_ndvi
# Out:
#     year  yield_corn  yield_soybean  yield_wheat        49        65  \
# 0   2000    8.591008       2.561342     2.823927  0.299674  0.309376
# 1   2001    8.673266       2.663958     2.701927  0.274885  0.278908
# 2   2002    8.118010       2.556752     2.356827  0.269621  0.258074
# 3   2003    8.924730       2.276952     2.971268  0.207908  0.259988
# 4   2004   10.063628       2.840494     2.902680  0.257877  0.289724
# 5   2005    9.285273       2.896130     2.823190  0.256467  0.272238
# 6   2006    9.357833       2.881782     2.598712  0.255455  0.290278
# 7   2007    9.458417       2.806695     2.704637  0.221122  0.275828
# 8   2008    9.621053       2.671862     3.014640  0.224796  0.256002
# 9   2009   10.318039       2.959524     2.980516  0.239662  0.281166
# 10  2010    9.575789       2.924330     3.102725  0.242846  0.283887
# 11  2011    9.214582       2.823252     2.933853  0.264892  0.285922
# 12  2012    7.726892       2.686798     3.106527  0.262406  0.298287
# 13  2013    9.925863       2.961524     3.167348  0.258361  0.273053
# 14  2014   10.732763       3.197781     2.937883  0.212588  0.239960
# 15  2015   10.572399       3.230623     2.930545  0.159558  0.268729
# 16  2016   10.960463       3.493606     3.540828  0.268943  0.324453
# 17  2017   11.083779       3.313418     3.117515  0.302560  0.319791
# 18  2018   11.074823       3.399769     3.200624  0.258351  0.271201
# 19  2019   10.510451       3.187490     3.474592  0.266418  0.284880
# 20  2020   10.760620       3.432721     3.341685  0.264691  0.288060
# 21  2021   11.089669       3.479287     2.980575  0.241217  0.290976
# 22  2022   10.788092       3.348137     3.127316  0.235063  0.274099
#
#           81        97       113       129       145       161       177  \
# 0   0.339785  0.362275  0.406583  0.480128  0.502755  0.554111  0.662831
# 1   0.295113  0.345418  0.392364  0.460058  0.519350  0.555456  0.668388
# 2   0.298917  0.339352  0.400822  0.442546  0.473739  0.544178  0.615975
# 3   0.319996  0.354274  0.418277  0.474236  0.510336  0.571130  0.635328
# 4   0.314624  0.360246  0.416114  0.464241  0.510547  0.599773  0.646286
# 5   0.319851  0.367782  0.421282  0.455442  0.511564  0.595489  0.679299
# 6   0.317984  0.356646  0.418583  0.468456  0.498606  0.565122  0.651256
# 7   0.347883  0.366519  0.411522  0.473419  0.541890  0.592407  0.681693
# 8   0.292174  0.332168  0.383002  0.443516  0.486440  0.540970  0.613237
# 9   0.312572  0.318933  0.378764  0.447520  0.485402  0.568330  0.628433
# 10  0.304359  0.364393  0.431308  0.470316  0.508410  0.631240  0.666698
# 11  0.310504  0.347015  0.391581  0.441015  0.482619  0.556764  0.623619
# 12  0.379570  0.408869  0.437123  0.464036  0.505326  0.567289  0.644223
# 13  0.313094  0.362977  0.370458  0.416672  0.492420  0.524396  0.632241
# 14  0.264764  0.309395  0.363729  0.410684  0.474261  0.550805  0.685028
# 15  0.726953  0.727433  0.716186  0.655789  0.560971
# 16  0.729277  0.743082  0.732034  0.693149  0.595301
# 17  0.709549  0.728202  0.735627  0.685275  0.585314
# 18  0.735786  0.740145  0.711233  0.665975  0.544260
# 19  0.690206  0.726670  0.732261  0.712244  0.637295
# 20  0.724524  0.756746  0.735915  0.674839  0.554219
# 21  0.733012  0.730786  0.712943  0.676915  0.557593
# 22  0.701679  0.728913  0.722191  0.694817  0.586123

# %% [markdown]
# ## **ANN - Corn Average MODIS**

# %%
predictions_corn_avg_ndvi = []
for year in all_years:
  print("YEAR ", year )
  test_df = avg_ndvi.loc[avg_ndvi['year'] == year]
  remaining_df = avg_ndvi.loc[(avg_ndvi.year != year)]
  
  # Separate Target Variable and Predictor Variables
  TargetVariable=['yield_corn']
  Predictors = avg_modis_day_cols +  ['year']
  
  y_train = remaining_df[TargetVariable].values
  X_train = remaining_df[Predictors].values

  y_test = test_df[TargetVariable].values
  X_test = test_df[Predictors].values
  
  ### Standardization of data ###
  PredictorScaler_train = StandardScaler()
  TargetVarScaler_train = StandardScaler()

  
  # Storing the fit object for later reference
  PredictorScalerFit_train = PredictorScaler_train.fit(X_train)
  TargetVarScalerFit_train = TargetVarScaler_train.fit(y_train)

  
  # Generating the standardized values of X and y
  X_train = PredictorScalerFit_train.transform(X_train)
  y_train = TargetVarScalerFit_train.transform(y_train)

  X_test = PredictorScalerFit_train.transform(X_test)
  y_test = TargetVarScalerFit_train.transform(y_test)
  
  
  # create ANN model
  model = Sequential()
  
  # Defining the Input layer and FIRST hidden layer, both are same!
  model.add(Dense(units=5, input_dim=15, kernel_initializer='normal', activation='relu'))
  
  # Defining the Second layer of the model
  # after the first layer we don't have to specify input_dim as keras configure it automatically
  model.add(Dense(units=5, kernel_initializer='normal', activation='tanh'))
  
  # The output neuron is a single fully connected node 
  # Since we will be predicting a single number
  model.add(Dense(1, kernel_initializer='normal'))
  
  # Compiling the model
  model.compile(loss='mean_squared_error', optimizer='adam')
  
  # Fitting the ANN to the Training set
  model.fit(X_train, y_train ,batch_size = 5, epochs = 500, verbose=0)

  # Generating Predictions on testing data
  Predictions=model.predict(X_test)
  
  # Scaling the predicted Price data back to original price scale
  Predictions=TargetVarScalerFit_train.inverse_transform(Predictions)
  
  predictions_corn_avg_ndvi.append(Predictions[0][0])
# Out:
# YEAR  2000
# 1/1 [==============================] - 0s 93ms/step
# YEAR  2001
# 1/1 [==============================] - 0s 60ms/step
# YEAR  2002
# 1/1 [==============================] - 0s 48ms/step
# YEAR  2003
# 1/1 [==============================] - 0s 52ms/step
# YEAR  2004
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f806edd2430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 53ms/step
# YEAR  2005
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f806ecb1700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 60ms/step
# YEAR  2006
# 1/1 [==============================] - 0s 46ms/step
# YEAR  2007
# 1/1 [==============================] - 0s 49ms/step
# YEAR  2008
# 1/1 [==============================] - 0s 53ms/step
# YEAR  2009
# 1/1 [==============================] - 0s 47ms/step
# YEAR  2010
# 1/1 [==============================] - 0s 55ms/step
# YEAR  2011
# 1/1 [==============================] - 0s 49ms/step
# YEAR  2012
# 1/1 [==============================] - 0s 55ms/step
# YEAR  2013
# 1/1 [==============================] - 0s 47ms/step
# YEAR  2014
# 1/1 [==============================] - 0s 48ms/step
# YEAR  2015
# 1/1 [==============================] - 0s 54ms/step
# YEAR  2016
# 1/1 [==============================] - 0s 69ms/step
# YEAR  2017
# 1/1 [==============================] - 0s 53ms/step
# YEAR  2018
# 1/1 [==============================] - 0s 65ms/step
# YEAR  2019
# 1/1 [==============================] - 0s 70ms/step
# YEAR  2020
# 1/1 [==============================] - 0s 55ms/step
# YEAR  2021
# 1/1 [==============================] - 0s 51ms/step
# YEAR  2022
# 1/1 [==============================] - 0s 62ms/step

# %%
predictions_corn_avg_ndvi
# Out:
# [8.233605,
#  9.283057,
#  8.173892,
#  8.740734,
#  9.938123,
#  9.083134,
#  8.946198,
#  9.784091,
#  9.536734,
#  10.243003,
#  9.707249,
#  10.1787,
#  8.366316,
#  9.097251,
#  10.996331,
#  9.983397,
#  11.373075,
#  10.465948,
#  10.022666,
#  10.968335,
#  11.157883,
#  11.134649,
#  10.135365]

# %%
avg_ndvi_predicted_corn = avg_ndvi.copy()

# %%
avg_ndvi_predicted_corn = avg_ndvi_predicted_corn[['year', 'yield_corn']]

# %%
avg_ndvi_predicted_corn['yield_corn_predicted'] = predictions_corn_avg_ndvi

# %%
avg_ndvi_predicted_corn
# Out:
#     year  yield_corn  yield_corn_predicted
# 0   2000    8.591008              8.233605
# 1   2001    8.673266              9.283057
# 2   2002    8.118010              8.173892
# 3   2003    8.924730              8.740734
# 4   2004   10.063628              9.938123
# 5   2005    9.285273              9.083134
# 6   2006    9.357833              8.946198
# 7   2007    9.458417              9.784091
# 8   2008    9.621053              9.536734
# 9   2009   10.318039             10.243003
# 10  2010    9.575789              9.707249
# 11  2011    9.214582             10.178700
# 12  2012    7.726892              8.366316
# 13  2013    9.925863              9.097251
# 14  2014   10.732763             10.996331
# 15  2015   10.572399              9.983397
# 16  2016   10.960463             11.373075
# 17  2017   11.083779             10.465948
# 18  2018   11.074823             10.022666
# 19  2019   10.510451             10.968335
# 20  2020   10.760620             11.157883
# 21  2021   11.089669             11.134649
# 22  2022   10.788092             10.135365

# %%
plt.rcParams["figure.figsize"] = (20,3)

plt.plot(avg_ndvi_predicted_corn['year'], avg_ndvi_predicted_corn['yield_corn'], color='red', marker='o', label='Actual Corn Yield')
plt.plot(avg_ndvi_predicted_corn['year'], avg_ndvi_predicted_corn['yield_corn_predicted'], color='blue', marker='o', label = 'Predicted Corn Yield')

plt.legend()
plt.xticks(np.arange(min(avg_ndvi_predicted_corn['year']), max(avg_ndvi_predicted_corn['year'])+1, 1.0))
plt.show()

# %%
#RMSE 
sqrt(mean_squared_error(avg_ndvi_predicted_corn['yield_corn'], avg_ndvi_predicted_corn['yield_corn_predicted']))
# Out:
# 0.5019364970930537

# %%
#R2
r2_score(avg_ndvi_predicted_corn['yield_corn'], avg_ndvi_predicted_corn['yield_corn_predicted'])
# Out:
# 0.7376547865691288

# %% [markdown]
# ## **ANN - SB Average MODIS**

# %%
predictions_sb_avg_ndvi = []

for year in all_years:
  print("YEAR ", year )
  test_df = avg_ndvi.loc[avg_ndvi['year'] == year]
  remaining_df = avg_ndvi.loc[(avg_ndvi.year != year)]
  # train_df = remaining_df[:11]
  # validation_df = remaining_df[11:]

  # Separate Target Variable and Predictor Variables
  TargetVariable=['yield_soybean']
  Predictors = avg_modis_day_cols + ['year']
  
  y_train = remaining_df[TargetVariable].values
  X_train = remaining_df[Predictors].values

  y_test = test_df[TargetVariable].values
  X_test = test_df[Predictors].values
  
  ### Sandardization of data ###
  PredictorScaler_train = StandardScaler()
  TargetVarScaler_train = StandardScaler()

  
  # Storing the fit object for later reference
  PredictorScalerFit_train = PredictorScaler_train.fit(X_train)
  TargetVarScalerFit_train = TargetVarScaler_train.fit(y_train)
  
  # Generating the standardized values of X and y
  X_train = PredictorScalerFit_train.transform(X_train)
  y_train = TargetVarScalerFit_train.transform(y_train)

  X_test = PredictorScalerFit_train.transform(X_test)
  y_test = TargetVarScalerFit_train.transform(y_test)
  
  # create ANN model
  model = Sequential()
  
  # Defining the Input layer and FIRST hidden layer, both are same!
  model.add(Dense(units=5, input_dim=15, kernel_initializer='normal', activation='relu'))
  
  # Defining the Second layer of the model
  # after the first layer we don't have to specify input_dim as keras configure it automatically
  model.add(Dense(units=5, kernel_initializer='normal', activation='tanh'))
  
  # The output neuron is a single fully connected node 
  # Since we will be predicting a single number
  model.add(Dense(1, kernel_initializer='normal'))
  
  # Compiling the model
  model.compile(loss='mean_squared_error', optimizer='adam')
  
  # Fitting the ANN to the Training set
  model.fit(X_train, y_train ,batch_size = 5, epochs = 500, verbose=0)

  # Generating Predictions on testing data
  Predictions=model.predict(X_test)
  
  # Scaling the predicted Price data back to original price scale
  Predictions=TargetVarScalerFit_train.inverse_transform(Predictions)
  
  predictions_sb_avg_ndvi.append(Predictions[0][0])
# Out:
# YEAR  2000
# 1/1 [==============================] - 0s 54ms/step
# YEAR  2001
# 1/1 [==============================] - 0s 57ms/step
# YEAR  2002
# 1/1 [==============================] - 0s 56ms/step
# YEAR  2003
# 1/1 [==============================] - 0s 48ms/step
# YEAR  2004
# 1/1 [==============================] - 0s 55ms/step
# YEAR  2005
# 1/1 [==============================] - 0s 61ms/step
# YEAR  2006
# 1/1 [==============================] - 0s 51ms/step
# YEAR  2007
# 1/1 [==============================] - 0s 50ms/step
# YEAR  2008
# 1/1 [==============================] - 0s 66ms/step
# YEAR  2009
# 1/1 [==============================] - 0s 51ms/step
# YEAR  2010
# 1/1 [==============================] - 0s 70ms/step
# YEAR  2011
# 1/1 [==============================] - 0s 76ms/step
# YEAR  2012
# 1/1 [==============================] - 0s 57ms/step
# YEAR  2013
# 1/1 [==============================] - 0s 61ms/step
# YEAR  2014
# 1/1 [==============================] - 0s 51ms/step
# YEAR  2015
# 1/1 [==============================] - 0s 55ms/step
# YEAR  2016
# 1/1 [==============================] - 0s 69ms/step
# YEAR  2017
# 1/1 [==============================] - 0s 49ms/step
# YEAR  2018
# 1/1 [==============================] - 0s 56ms/step
# YEAR  2019
# 1/1 [==============================] - 0s 78ms/step
# YEAR  2020
# 1/1 [==============================] - 0s 62ms/step
# YEAR  2021
# 1/1 [==============================] - 0s 57ms/step
# YEAR  2022
# 1/1 [==============================] - 0s 55ms/step

# %%
predictions_sb_avg_ndvi
# Out:
# [2.4826252,
#  2.7583666,
#  2.4874632,
#  2.547614,
#  2.8822489,
#  2.9333017,
#  2.740933,
#  2.6142802,
#  2.5672426,
#  3.069907,
#  2.7931163,
#  2.8983164,
#  2.6529508,
#  3.0661383,
#  3.2862782,
#  3.2936146,
#  3.4400196,
#  3.3452322,
#  3.3683925,
#  3.1455035,
#  3.4230282,
#  3.4994912,
#  3.1743808]

# %%
avg_ndvi_predicted_sb = avg_ndvi.copy()
avg_ndvi_predicted_sb = avg_ndvi_predicted_sb[['year', 'yield_soybean']]
avg_ndvi_predicted_sb['yield_soybean_predicted'] = predictions_sb_avg_ndvi

# %%
# plt.rcParams["figure.figsize"] = (20,3)

plt.plot(avg_ndvi_predicted_sb['year'], avg_ndvi_predicted_sb['yield_soybean'], color='red', marker='o', label='Actual Soybean Yield')
plt.plot(avg_ndvi_predicted_sb['year'], avg_ndvi_predicted_sb['yield_soybean_predicted'], color='blue', marker='o', label = 'Predicted Soybean Yield')

plt.legend()
plt.xticks(np.arange(min(avg_ndvi_predicted_sb['year']), max(avg_ndvi_predicted_sb['year'])+1, 1.0))
plt.show()

# %%
#RMSE 
sqrt(mean_squared_error(avg_ndvi_predicted_sb['yield_soybean'], avg_ndvi_predicted_sb['yield_soybean_predicted']))
# Out:
# 0.10639366265734852

# %%
#R2
r2_score(avg_ndvi_predicted_sb['yield_soybean'], avg_ndvi_predicted_sb['yield_soybean_predicted'])
# Out:
# 0.8966119726611544

# %% [markdown]
# ## **ANN - Wheat Average MODIS**

# %%
predictions_wheat_avg_ndvi = []

for year in all_years:
  print("YEAR ", year )
  test_df = avg_ndvi.loc[avg_ndvi['year'] == year]
  remaining_df = avg_ndvi.loc[(avg_ndvi.year != year)]
  # train_df = remaining_df[:11]
  # validation_df = remaining_df[11:]

  # Separate Target Variable and Predictor Variables
  TargetVariable=['yield_wheat']
  Predictors = avg_modis_day_cols + ['year']
  
  y_train = remaining_df[TargetVariable].values
  X_train = remaining_df[Predictors].values

  y_test = test_df[TargetVariable].values
  X_test = test_df[Predictors].values
  
  ### Sandardization of data ###
  PredictorScaler_train = StandardScaler()
  TargetVarScaler_train = StandardScaler()
  
  # Storing the fit object for later reference
  PredictorScalerFit_train = PredictorScaler_train.fit(X_train)
  TargetVarScalerFit_train = TargetVarScaler_train.fit(y_train)

  # Generating the standardized values of X and y
  X_train = PredictorScalerFit_train.transform(X_train)
  y_train = TargetVarScalerFit_train.transform(y_train)

  X_test = PredictorScalerFit_train.transform(X_test)
  y_test = TargetVarScalerFit_train.transform(y_test)
  
  # create ANN model
  model = Sequential()
  
  # Defining the Input layer and FIRST hidden layer, both are same!
  model.add(Dense(units=5, input_dim=15, kernel_initializer='normal', activation='relu'))
  
  # Defining the Second layer of the model
  # after the first layer we don't have to specify input_dim as keras configure it automatically
  model.add(Dense(units=5, kernel_initializer='normal', activation='tanh'))
  
  # The output neuron is a single fully connected node 
  # Since we will be predicting a single number
  model.add(Dense(1, kernel_initializer='normal'))
  
  # Compiling the model
  model.compile(loss='mean_squared_error', optimizer='adam')
  
  # Fitting the ANN to the Training set
  model.fit(X_train, y_train ,batch_size = 5, epochs = 500, verbose=0)

  # Generating Predictions on testing data
  Predictions=model.predict(X_test)
  
  # Scaling the predicted Price data back to original price scale
  Predictions=TargetVarScalerFit_train.inverse_transform(Predictions)
  
  predictions_wheat_avg_ndvi.append(Predictions[0][0])
# Out:
# YEAR  2000
# 1/1 [==============================] - 1s 506ms/step
# YEAR  2001
# 1/1 [==============================] - 0s 59ms/step
# YEAR  2002
# 1/1 [==============================] - 0s 53ms/step
# YEAR  2003
# 1/1 [==============================] - 0s 63ms/step
# YEAR  2004
# 1/1 [==============================] - 0s 61ms/step
# YEAR  2005
# 1/1 [==============================] - 0s 60ms/step
# YEAR  2006
# 1/1 [==============================] - 0s 149ms/step
# YEAR  2007
# 1/1 [==============================] - 0s 101ms/step
# YEAR  2008
# 1/1 [==============================] - 0s 55ms/step
# YEAR  2009
# 1/1 [==============================] - 0s 67ms/step
# YEAR  2010
# 1/1 [==============================] - 0s 57ms/step
# YEAR  2011
# 1/1 [==============================] - 0s 60ms/step
# YEAR  2012
# 1/1 [==============================] - 0s 53ms/step
# YEAR  2013
# 1/1 [==============================] - 0s 67ms/step
# YEAR  2014
# 1/1 [==============================] - 0s 60ms/step
# YEAR  2015
# 1/1 [==============================] - 0s 68ms/step
# YEAR  2016
# 1/1 [==============================] - 0s 61ms/step
# YEAR  2017
# 1/1 [==============================] - 0s 61ms/step
# YEAR  2018
# 1/1 [==============================] - 0s 72ms/step
# YEAR  2019
# 1/1 [==============================] - 0s 60ms/step
# YEAR  2020
# 1/1 [==============================] - 0s 58ms/step
# YEAR  2021
# 1/1 [==============================] - 0s 51ms/step
# YEAR  2022
# 1/1 [==============================] - 0s 57ms/step

# %%
predictions_wheat_avg_ndvi
# Out:
# [2.3581111,
#  2.7577465,
#  3.0076962,
#  2.539329,
#  3.1055737,
#  2.4418478,
#  2.579081,
#  3.0082073,
#  2.6332252,
#  3.4249659,
#  3.0680184,
#  2.825129,
#  2.3350103,
#  3.2840414,
#  3.1589575,
#  3.0486472,
#  3.117512,
#  3.495091,
#  2.563196,
#  3.3394275,
#  3.0824704,
#  3.1788871,
#  3.2880015]

# %%
avg_ndvi_predicted_wheat = avg_ndvi.copy()
avg_ndvi_predicted_wheat = avg_ndvi_predicted_wheat[['year', 'yield_wheat']]
avg_ndvi_predicted_wheat['yield_wheat_predicted'] = predictions_wheat_avg_ndvi

# %%
plt.plot(avg_ndvi_predicted_wheat['year'], avg_ndvi_predicted_wheat['yield_wheat'], color='red', marker='o', label='Actual Wheat Yield')
plt.plot(avg_ndvi_predicted_wheat['year'], avg_ndvi_predicted_wheat['yield_wheat_predicted'], color='blue', marker='o', label = 'Predicted Wheat Yield')

plt.legend()
plt.xticks(np.arange(min(avg_ndvi_predicted_wheat['year']), max(avg_ndvi_predicted_wheat['year'])+1, 1.0))
plt.show()

# %%
#calculate RMSE
sqrt(mean_squared_error(avg_ndvi_predicted_wheat['yield_wheat'], avg_ndvi_predicted_wheat['yield_wheat_predicted']))
# Out:
# 0.36210916051322134

# %%
#R2
r2_score(avg_ndvi_predicted_wheat['yield_wheat'], avg_ndvi_predicted_wheat['yield_wheat_predicted'])
# Out:
# -0.8956416741562088
