# %% [markdown]
# #CSCI 8523 Fall 2022 - Phase I Modeling
# #### Maitrayee Deka
#
# ---
#
#
#
# ---

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

from keras.models import Sequential
from keras.layers import Dense

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import mean_squared_error
from math import sqrt

from sklearn.metrics import r2_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
modis_bins_5 = pd.read_csv('/content/drive/Shareddrives/CSCI 8523 F22/Data/modis_bins_5.csv')

# %%
modis_bins_5
# Out:
#     year  yield_corn  yield_soybean  yield_wheat     49_0     49_1    49_2  \
# 0   2000    8.591008       2.561342     2.823927   3721.0  50755.0  8987.0
# 1   2001    8.673266       2.663958     2.701927   6734.0  26499.0  4038.0
# 2   2002    8.118010       2.556752     2.356827  11084.0  45156.0  6888.0
# 3   2003    8.924730       2.276952     2.971268  23726.0  25381.0  6195.0
# 4   2004   10.063628       2.840494     2.902680  10677.0  31355.0  3923.0
# 5   2005    9.285273       2.896130     2.823190  14290.0  36967.0  7268.0
# 6   2006    9.357833       2.881782     2.598712  12382.0  38977.0  6303.0
# 7   2007    9.458417       2.806695     2.704637  16703.0  23991.0  5082.0
# 8   2008    9.621053       2.671862     3.014640  17349.0  23518.0  6655.0
# 9   2009   10.318039       2.959524     2.980516  12880.0  37660.0  3985.0
# 10  2010    9.575789       2.924330     3.102725   9662.0  19322.0  2825.0
# 11  2011    9.214582       2.823252     2.933853   8834.0  33047.0  5766.0
# 12  2012    7.726892       2.686798     3.106527  14087.0  39379.0  8578.0
# 13  2013    9.925863       2.961524     3.167348  13465.0  23646.0  8960.0
# 14  2014   10.732763       3.197781     2.937883  15198.0  27837.0  2924.0
# 15  2015   10.572399       3.230623     2.930545  29144.0  17171.0  4064.0
# 16  2016   10.960463       3.493606     3.540828  12511.0  37648.0  8792.0
# 17  2017   11.083779       3.313418     3.117515   5814.0  42831.0  9991.0
# 18  2018   11.074823       3.399769     3.200624  10301.0  36927.0  5085.0
# 19  2019   10.510451       3.187490     3.474592   9321.0  18808.0  6039.0
# 20  2020   10.760620       3.432721     3.341685  10308.0  33512.0  6859.0
# 21  2021   11.089669       3.479287     2.980575  15145.0  37088.0  5411.0
# 22  2022   10.788092       3.348137     3.127316  15885.0  34518.0  5565.0
#
#      49_3  49_4     65_0  ...  241_0   241_1    241_2    241_3    241_4  \
# 0   649.0   1.0   2936.0  ...  380.0  8343.0  14887.0  36215.0   4670.0
# 1   505.0   1.0   7338.0  ...  483.0  7360.0  13464.0  33863.0   9325.0
# 2   543.0   5.0  14058.0  ...  340.0  5794.0  14753.0  35061.0   8547.0
# 3   742.0   4.0  12201.0  ...  518.0  8461.0  15339.0  37214.0   2963.0
# 4   694.0   4.0   6266.0  ...  408.0  4501.0  13096.0  32124.0  14366.0
# 5   951.0  26.0  11049.0  ...  437.0  4904.0  12800.0  40002.0   6352.0
# 6   330.0   0.0   7327.0  ...  355.0  6523.0  12313.0  34096.0  11208.0
# 7   211.0   1.0   7773.0  ...  445.0  5811.0  14983.0  37890.0   5366.0
# 8   424.0   4.0  13611.0  ...  406.0  4997.0  11479.0  33755.0  13858.0
# 9   584.0   2.0   6228.0  ...  401.0  4613.0  10750.0  28890.0  19841.0
# 10  723.0  11.0   8396.0  ...  223.0  5037.0  15174.0  41031.0   3030.0
# 11  478.0   0.0   6422.0  ...  125.0  6407.0  10833.0  33180.0  13949.0
# 12  529.0   0.0   6019.0  ...  393.0  8980.0  20736.0  32480.0   1906.0
# 13  403.0   1.0  11803.0  ...  269.0  4809.0  11872.0  32929.0  14616.0
# 14  159.0   0.0  11973.0  ...  405.0  4401.0   9488.0  27516.0  22685.0
# 15  659.0  13.0   6108.0  ...  308.0  5710.0  12970.0  34954.0  10553.0
# 16  790.0  18.0   1689.0  ...  391.0  4661.0  10004.0  29124.0  20315.0
# 17  654.0   7.0   3992.0  ...  272.0  4567.0  10964.0  32614.0  16078.0
# 18  385.0   0.0   7956.0  ...  328.0  5703.0  11402.0  35639.0  11423.0
# 19  563.0   1.0   6995.0  ...  247.0  3905.0   9743.0  26124.0  24476.0
# 20  625.0   2.0   7342.0  ...  333.0  4988.0  10544.0  36193.0  12437.0
# 21  289.0   3.0   3924.0  ...  467.0  4695.0  11987.0  31824.0  15522.0
# 22  454.0  12.0   8766.0  ...  446.0  5615.0  10797.0  22627.0  25010.0
#
#     257_0    257_1    257_2    257_3   257_4
# 0   638.0  13993.0  30788.0  18661.0   415.0
# 1   600.0   9861.0  24999.0  28843.0   192.0
# 2   383.0   7576.0  28344.0  27799.0   393.0
# 3   571.0  10172.0  30737.0  22272.0   743.0
# 4   261.0   7232.0  25127.0  31447.0   428.0
# 5   463.0   8290.0  34764.0  20884.0    94.0
# 6   328.0   8673.0  24508.0  30668.0   318.0
# 7   678.0   9561.0  33176.0  21035.0    45.0
# 8   597.0   5954.0  19328.0  37610.0  1006.0
# 9   414.0   6262.0  21122.0  36048.0   649.0
# 10  262.0   9535.0  34312.0  20351.0    35.0
# 11  162.0   8685.0  25572.0  28940.0  1136.0
# 12  588.0  18355.0  26014.0  19468.0    70.0
# 13  269.0   5994.0  20652.0  36995.0   585.0
# 14  499.0   5659.0  16607.0  40609.0  1121.0
# 15  264.0   8168.0  28117.0  27675.0   271.0
# 16  542.0   5867.0  22007.0  35148.0   931.0
# 17  426.0   6662.0  22852.0  34178.0   377.0
# 18  343.0   8932.0  32142.0  22635.0   443.0
# 19  342.0   4907.0  14371.0  41392.0  3483.0
# 20  312.0   9602.0  27297.0  26734.0   550.0
# 21  457.0   6934.0  30701.0  26090.0   313.0
# 22  375.0   8822.0  21127.0  32395.0  1776.0
#
# [23 rows x 74 columns]

# %%
all_years = list(modis_bins_5['year'].values)

# %%
modis_day_cols = list(modis_bins_5.columns)[4:]

# %%
len(modis_day_cols)
# Out:
# 70

# %% [markdown]
# ## **ANN - Corn Average MODIS**

# %%
predictions_corn = []
for year in all_years:
  print("YEAR ", year )
  test_df = modis_bins_5.loc[modis_bins_5['year'] == year]
  remaining_df = modis_bins_5.loc[(modis_bins_5.year != year)]
  
  # Separate Target Variable and Predictor Variables
  TargetVariable=['yield_corn']
  Predictors = modis_day_cols +  ['year']
  
  y_train = remaining_df[TargetVariable].values
  X_train = remaining_df[Predictors].values

  y_test = test_df[TargetVariable].values
  X_test = test_df[Predictors].values
  
  ### Standardization of data ###
  PredictorScaler_train = StandardScaler()
  TargetVarScaler_train = StandardScaler()

  
  # Storing the fit object for later reference
  PredictorScalerFit_train = PredictorScaler_train.fit(X_train)
  TargetVarScalerFit_train = TargetVarScaler_train.fit(y_train)

  
  # Generating the standardized values of X and y
  X_train = PredictorScalerFit_train.transform(X_train)
  y_train = TargetVarScalerFit_train.transform(y_train)

  X_test = PredictorScalerFit_train.transform(X_test)
  y_test = TargetVarScalerFit_train.transform(y_test)
  
  
  # create ANN model
  model = Sequential()
  
  # Defining the Input layer and FIRST hidden layer, both are same!
  model.add(Dense(units=5, input_dim=71, kernel_initializer='normal', activation='relu'))
  
  # Defining the Second layer of the model
  # after the first layer we don't have to specify input_dim as keras configure it automatically
  model.add(Dense(units=5, kernel_initializer='normal', activation='tanh'))
  
  # The output neuron is a single fully connected node 
  # Since we will be predicting a single number
  model.add(Dense(1, kernel_initializer='normal'))
  
  # Compiling the model
  model.compile(loss='mean_squared_error', optimizer='adam')
  
  # Fitting the ANN to the Training set
  model.fit(X_train, y_train ,batch_size = 5, epochs = 500, verbose=0)

  # Generating Predictions on testing data
  Predictions=model.predict(X_test)
  
  # Scaling the predicted Price data back to original price scale
  Predictions=TargetVarScalerFit_train.inverse_transform(Predictions)
  
  predictions_corn.append(Predictions[0][0])
# Out:
# YEAR  2000
# 1/1 [==============================] - 0s 67ms/step
# YEAR  2001
# 1/1 [==============================] - 0s 42ms/step
# YEAR  2002
# 1/1 [==============================] - 0s 37ms/step
# YEAR  2003
# 1/1 [==============================] - 0s 42ms/step
# YEAR  2004
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fdb686a3160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 42ms/step
# YEAR  2005
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fdb685e2dc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 49ms/step
# YEAR  2006
# 1/1 [==============================] - 0s 37ms/step
# YEAR  2007
# 1/1 [==============================] - 0s 41ms/step
# YEAR  2008
# 1/1 [==============================] - 0s 47ms/step
# YEAR  2009
# 1/1 [==============================] - 0s 39ms/step
# YEAR  2010
# 1/1 [==============================] - 0s 38ms/step
# YEAR  2011
# 1/1 [==============================] - 0s 43ms/step
# YEAR  2012
# 1/1 [==============================] - 0s 37ms/step
# YEAR  2013
# 1/1 [==============================] - 0s 40ms/step
# YEAR  2014
# 1/1 [==============================] - 0s 37ms/step
# YEAR  2015
# 1/1 [==============================] - 0s 38ms/step
# YEAR  2016
# 1/1 [==============================] - 0s 37ms/step
# YEAR  2017
# 1/1 [==============================] - 0s 37ms/step
# YEAR  2018
# 1/1 [==============================] - 0s 37ms/step
# YEAR  2019
# 1/1 [==============================] - 0s 36ms/step
# YEAR  2020
# 1/1 [==============================] - 0s 39ms/step
# YEAR  2021
# 1/1 [==============================] - 0s 37ms/step
# YEAR  2022
# 1/1 [==============================] - 0s 44ms/step

# %%
predictions_corn
# Out:
# [8.185971,
#  9.861613,
#  9.117059,
#  8.443906,
#  9.877512,
#  8.912725,
#  8.61413,
#  8.224655,
#  9.900023,
#  10.439571,
#  9.8272295,
#  9.8871,
#  8.376422,
#  8.7960615,
#  10.939813,
#  9.880487,
#  10.6449995,
#  10.7717905,
#  10.410653,
#  9.9549,
#  10.779166,
#  11.02636,
#  10.100969]

# %%
bin_5_ndvi_predicted_corn = modis_bins_5.copy()

# %%
bin_5_ndvi_predicted_corn = bin_5_ndvi_predicted_corn[['year', 'yield_corn']]

# %%
bin_5_ndvi_predicted_corn['yield_corn_predicted'] = predictions_corn

# %%
bin_5_ndvi_predicted_corn
# Out:
#     year  yield_corn  yield_corn_predicted
# 0   2000    8.591008              8.185971
# 1   2001    8.673266              9.861613
# 2   2002    8.118010              9.117059
# 3   2003    8.924730              8.443906
# 4   2004   10.063628              9.877512
# 5   2005    9.285273              8.912725
# 6   2006    9.357833              8.614130
# 7   2007    9.458417              8.224655
# 8   2008    9.621053              9.900023
# 9   2009   10.318039             10.439571
# 10  2010    9.575789              9.827229
# 11  2011    9.214582              9.887100
# 12  2012    7.726892              8.376422
# 13  2013    9.925863              8.796062
# 14  2014   10.732763             10.939813
# 15  2015   10.572399              9.880487
# 16  2016   10.960463             10.645000
# 17  2017   11.083779             10.771791
# 18  2018   11.074823             10.410653
# 19  2019   10.510451              9.954900
# 20  2020   10.760620             10.779166
# 21  2021   11.089669             11.026360
# 22  2022   10.788092             10.100969

# %%
plt.rcParams["figure.figsize"] = (20,3)

plt.plot(bin_5_ndvi_predicted_corn['year'], bin_5_ndvi_predicted_corn['yield_corn'], color='red', marker='o', label='Actual Corn Yield')
plt.plot(bin_5_ndvi_predicted_corn['year'], bin_5_ndvi_predicted_corn['yield_corn_predicted'], color='blue', marker='o', label = 'Predicted Corn Yield')

plt.legend()
plt.xticks(np.arange(min(bin_5_ndvi_predicted_corn['year']), max(bin_5_ndvi_predicted_corn['year'])+1, 1.0))
plt.show()

# %%
#calculate RMSE
sqrt(mean_squared_error(bin_5_ndvi_predicted_corn['yield_corn'], bin_5_ndvi_predicted_corn['yield_corn_predicted']))
# Out:
# 0.6360666029862188

# %%
#R2
r2_score(bin_5_ndvi_predicted_corn['yield_corn'], bin_5_ndvi_predicted_corn['yield_corn_predicted'])
# Out:
# 0.5787103590821862

# %% [markdown]
# ## **ANN - SB Average MODIS**

# %%
predictions_sb = []

for year in all_years:
  print("YEAR ", year )
  test_df = modis_bins_5.loc[modis_bins_5['year'] == year]
  remaining_df = modis_bins_5.loc[(modis_bins_5.year != year)]
  

  # Separate Target Variable and Predictor Variables
  TargetVariable=['yield_soybean']
  Predictors = modis_day_cols + ['year']
  
  y_train = remaining_df[TargetVariable].values
  X_train = remaining_df[Predictors].values

  y_test = test_df[TargetVariable].values
  X_test = test_df[Predictors].values
  
  ### Sandardization of data ###
  PredictorScaler_train = StandardScaler()
  TargetVarScaler_train = StandardScaler()

  
  # Storing the fit object for later reference
  PredictorScalerFit_train = PredictorScaler_train.fit(X_train)
  TargetVarScalerFit_train = TargetVarScaler_train.fit(y_train)
  
  # Generating the standardized values of X and y
  X_train = PredictorScalerFit_train.transform(X_train)
  y_train = TargetVarScalerFit_train.transform(y_train)

  X_test = PredictorScalerFit_train.transform(X_test)
  y_test = TargetVarScalerFit_train.transform(y_test)
  
  # create ANN model
  model = Sequential()
  
  # Defining the Input layer and FIRST hidden layer, both are same!
  model.add(Dense(units=5, input_dim=71, kernel_initializer='normal', activation='relu'))
  
  # Defining the Second layer of the model
  # after the first layer we don't have to specify input_dim as keras configure it automatically
  model.add(Dense(units=5, kernel_initializer='normal', activation='tanh'))
  
  # The output neuron is a single fully connected node 
  # Since we will be predicting a single number
  model.add(Dense(1, kernel_initializer='normal'))
  
  # Compiling the model
  model.compile(loss='mean_squared_error', optimizer='adam')
  
  # Fitting the ANN to the Training set
  model.fit(X_train, y_train ,batch_size = 5, epochs = 500, verbose=0)

  # Generating Predictions on testing data
  Predictions=model.predict(X_test)
  
  # Scaling the predicted Price data back to original price scale
  Predictions=TargetVarScalerFit_train.inverse_transform(Predictions)
  
  predictions_sb.append(Predictions[0][0])
# Out:
# YEAR  2000
# 1/1 [==============================] - 0s 40ms/step
# YEAR  2001
# 1/1 [==============================] - 0s 39ms/step
# YEAR  2002
# 1/1 [==============================] - 0s 40ms/step
# YEAR  2003
# 1/1 [==============================] - 0s 62ms/step
# YEAR  2004
# 1/1 [==============================] - 0s 40ms/step
# YEAR  2005
# 1/1 [==============================] - 0s 38ms/step
# YEAR  2006
# 1/1 [==============================] - 0s 38ms/step
# YEAR  2007
# 1/1 [==============================] - 0s 118ms/step
# YEAR  2008
# 1/1 [==============================] - 0s 42ms/step
# YEAR  2009
# 1/1 [==============================] - 0s 39ms/step
# YEAR  2010
# 1/1 [==============================] - 0s 48ms/step
# YEAR  2011
# 1/1 [==============================] - 0s 38ms/step
# YEAR  2012
# 1/1 [==============================] - 0s 37ms/step
# YEAR  2013
# 1/1 [==============================] - 0s 39ms/step
# YEAR  2014
# 1/1 [==============================] - 0s 44ms/step
# YEAR  2015
# 1/1 [==============================] - 0s 38ms/step
# YEAR  2016
# 1/1 [==============================] - 0s 39ms/step
# YEAR  2017
# 1/1 [==============================] - 0s 42ms/step
# YEAR  2018
# 1/1 [==============================] - 0s 39ms/step
# YEAR  2019
# 1/1 [==============================] - 0s 36ms/step
# YEAR  2020
# 1/1 [==============================] - 0s 37ms/step
# YEAR  2021
# 1/1 [==============================] - 0s 37ms/step
# YEAR  2022
# 1/1 [==============================] - 0s 40ms/step

# %%
predictions_sb
# Out:
# [2.576112,
#  2.4530382,
#  2.6180696,
#  2.660296,
#  2.8120313,
#  2.9209063,
#  2.494398,
#  2.61359,
#  2.639565,
#  3.0364304,
#  2.8191807,
#  3.0312006,
#  2.458316,
#  3.1835299,
#  3.3317888,
#  3.1199243,
#  3.3533683,
#  3.4602354,
#  2.8856366,
#  2.8002443,
#  3.24751,
#  3.4310238,
#  2.9513412]

# %%
bin_5_ndvi_predicted_sb = modis_bins_5.copy()
bin_5_ndvi_predicted_sb = bin_5_ndvi_predicted_sb[['year', 'yield_soybean']]
bin_5_ndvi_predicted_sb['yield_soybean_predicted'] = predictions_sb

# %%
plt.plot(bin_5_ndvi_predicted_sb['year'], bin_5_ndvi_predicted_sb['yield_soybean'], color='red', marker='o', label='Actual Soybean Yield')
plt.plot(bin_5_ndvi_predicted_sb['year'], bin_5_ndvi_predicted_sb['yield_soybean_predicted'], color='blue', marker='o', label = 'Predicted Soybean Yield')

plt.legend()
plt.xticks(np.arange(min(bin_5_ndvi_predicted_sb['year']), max(bin_5_ndvi_predicted_sb['year'])+1, 1.0))
plt.show()

# %%
#calculate RMSE
sqrt(mean_squared_error(bin_5_ndvi_predicted_sb['yield_soybean'], bin_5_ndvi_predicted_sb['yield_soybean_predicted']))
# Out:
# 0.23094798509142972

# %%
#R2
r2_score(bin_5_ndvi_predicted_sb['yield_soybean'], bin_5_ndvi_predicted_sb['yield_soybean_predicted'])
# Out:
# 0.5128450898645442

# %% [markdown]
# ## **ANN - Wheat Average MODIS**

# %%
predictions_wheat = []

for year in all_years:
  print("YEAR ", year )
  test_df = modis_bins_5.loc[modis_bins_5['year'] == year]
  remaining_df = modis_bins_5.loc[(modis_bins_5.year != year)]

  # Separate Target Variable and Predictor Variables
  TargetVariable=['yield_wheat']
  Predictors = modis_day_cols + ['year']
  
  y_train = remaining_df[TargetVariable].values
  X_train = remaining_df[Predictors].values

  y_test = test_df[TargetVariable].values
  X_test = test_df[Predictors].values
  
  ### Sandardization of data ###
  PredictorScaler_train = StandardScaler()
  TargetVarScaler_train = StandardScaler()
  
  # Storing the fit object for later reference
  PredictorScalerFit_train = PredictorScaler_train.fit(X_train)
  TargetVarScalerFit_train = TargetVarScaler_train.fit(y_train)

  # Generating the standardized values of X and y
  X_train = PredictorScalerFit_train.transform(X_train)
  y_train = TargetVarScalerFit_train.transform(y_train)

  X_test = PredictorScalerFit_train.transform(X_test)
  y_test = TargetVarScalerFit_train.transform(y_test)
  
  # create ANN model
  model = Sequential()
  
  # Defining the Input layer and FIRST hidden layer, both are same!
  model.add(Dense(units=5, input_dim=71, kernel_initializer='normal', activation='relu'))
  
  # Defining the Second layer of the model
  # after the first layer we don't have to specify input_dim as keras configure it automatically
  model.add(Dense(units=5, kernel_initializer='normal', activation='tanh'))
  
  # The output neuron is a single fully connected node 
  # Since we will be predicting a single number
  model.add(Dense(1, kernel_initializer='normal'))
  
  # Compiling the model
  model.compile(loss='mean_squared_error', optimizer='adam')
  
  # Fitting the ANN to the Training set
  model.fit(X_train, y_train ,batch_size = 5, epochs = 500, verbose=0)

  # Generating Predictions on testing data
  Predictions=model.predict(X_test)
  
  # Scaling the predicted Price data back to original price scale
  Predictions=TargetVarScalerFit_train.inverse_transform(Predictions)
  
  predictions_wheat.append(Predictions[0][0])
# Out:
# YEAR  2000
# 1/1 [==============================] - 0s 47ms/step
# YEAR  2001
# 1/1 [==============================] - 0s 79ms/step
# YEAR  2002
# 1/1 [==============================] - 0s 37ms/step
# YEAR  2003
# 1/1 [==============================] - 0s 42ms/step
# YEAR  2004
# 1/1 [==============================] - 0s 41ms/step
# YEAR  2005
# 1/1 [==============================] - 0s 42ms/step
# YEAR  2006
# 1/1 [==============================] - 0s 47ms/step
# YEAR  2007
# 1/1 [==============================] - 0s 39ms/step
# YEAR  2008
# 1/1 [==============================] - 0s 41ms/step
# YEAR  2009
# 1/1 [==============================] - 0s 45ms/step
# YEAR  2010
# 1/1 [==============================] - 0s 46ms/step
# YEAR  2011
# 1/1 [==============================] - 0s 39ms/step
# YEAR  2012
# 1/1 [==============================] - 0s 43ms/step
# YEAR  2013
# 1/1 [==============================] - 0s 41ms/step
# YEAR  2014
# 1/1 [==============================] - 0s 39ms/step
# YEAR  2015
# 1/1 [==============================] - 0s 40ms/step
# YEAR  2016
# 1/1 [==============================] - 0s 41ms/step
# YEAR  2017
# 1/1 [==============================] - 0s 72ms/step
# YEAR  2018
# 1/1 [==============================] - 0s 59ms/step
# YEAR  2019
# 1/1 [==============================] - 0s 50ms/step
# YEAR  2020
# 1/1 [==============================] - 0s 95ms/step
# YEAR  2021
# 1/1 [==============================] - 0s 61ms/step
# YEAR  2022
# 1/1 [==============================] - 0s 54ms/step

# %%
predictions_wheat
# Out:
# [3.037713,
#  2.6032543,
#  2.9651098,
#  2.615729,
#  3.2192652,
#  3.4334903,
#  2.7105734,
#  3.252718,
#  2.440716,
#  3.2827563,
#  2.8023689,
#  3.0539064,
#  2.6511908,
#  3.0694327,
#  3.084173,
#  3.2400894,
#  2.8765411,
#  3.4902704,
#  2.8933954,
#  3.344268,
#  3.1807775,
#  3.052347,
#  3.0214012]

# %%
bin_5_ndvi_predicted_wheat = modis_bins_5.copy()
bin_5_ndvi_predicted_wheat = bin_5_ndvi_predicted_wheat[['year', 'yield_wheat']]
bin_5_ndvi_predicted_wheat['yield_wheat_predicted'] = predictions_wheat

# %%
plt.plot(bin_5_ndvi_predicted_wheat['year'], bin_5_ndvi_predicted_wheat['yield_wheat'], color='red', marker='o', label='Actual Wheat Yield')
plt.plot(bin_5_ndvi_predicted_wheat['year'], bin_5_ndvi_predicted_wheat['yield_wheat_predicted'], color='blue', marker='o', label = 'Predicted Wheat Yield')

plt.legend()
plt.xticks(np.arange(min(bin_5_ndvi_predicted_wheat['year']), max(bin_5_ndvi_predicted_wheat['year'])+1, 1.0))
plt.show()

# %%
#calculate RMSE
sqrt(mean_squared_error(bin_5_ndvi_predicted_wheat['yield_wheat'], bin_5_ndvi_predicted_wheat['yield_wheat_predicted']))
# Out:
# 0.3569688571571207

# %%
#R2
r2_score(bin_5_ndvi_predicted_wheat['yield_wheat'], bin_5_ndvi_predicted_wheat['yield_wheat_predicted'])
# Out:
# -0.8422046842053599
